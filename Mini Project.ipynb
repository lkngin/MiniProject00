# %% [markdown]
# Title:
# Sephora Website
#
# Author:
# Raghad Alharbi
#
# Date:
# 7 days ago
#
# Purpose:
# To understand products sold in Sephora.
#
# Methodology:
#
# Findings:
#
# Recommendation/Conclusion:

# %% [markdown]
# <img src='./Images/Sephora.jpg'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
sns.set(color_codes=True)

# %% [markdown]
# Import Sephora Website Dataset

# %%
colnames = ['category', 'brand', 'rating', 'number_of_reviews', 'love', 'price', 'value_price', 'ingredients']
dfSephora = pd.read_csv('sephora_website_dataset.csv', usecols = colnames)

# %%
dfSephora
# Out:
#                    brand            category  rating  number_of_reviews  love  \
# 0         Acqua Di Parma           Fragrance     4.0                  4  3002
# 1         Acqua Di Parma             Cologne     4.5                 76  2700
# 2         Acqua Di Parma             Perfume     4.5                 26  2600
# 3         Acqua Di Parma             Perfume     4.5                 23  2900
# 4         Acqua Di Parma           Fragrance     3.5                  2   943
# ...                  ...                 ...     ...                ...   ...
# 9163  SEPHORA COLLECTION          Face Masks     2.0                 15  6200
# 9164  SEPHORA COLLECTION            Lip Sets     0.0                  0   266
# 9165  SEPHORA COLLECTION  Tinted Moisturizer     0.0                  0   445
# 9166  SEPHORA COLLECTION         no category     5.0                 46     0
# 9167  SEPHORA COLLECTION         no category     0.0                  0     0
#
# ...

# %% [markdown]
# Find the information of the dataset

# %%
dfSephora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9168 entries, 0 to 9167
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              9168 non-null   object
#  1   category           9168 non-null   object
#  2   rating             9168 non-null   float64
#  3   number_of_reviews  9168 non-null   int64
#  4   love               9168 non-null   int64
#  5   price              9168 non-null   float64
#  6   value_price        9168 non-null   float64
#  7   ingredients        9168 non-null   object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 573.1+ KB

# %% [markdown]
# Top 10 brands highest rating and love then categories them

# %% [markdown]
# 1. Sort the rating and love. Select top 10.

# %%
dfTop = dfSephora.sort_values(by=['rating', 'love'], ascending=False).head(10)

# %%
dfCB = dfTop.groupby(['brand'])
dfCB.first()
# Out:
#                                 category  rating  number_of_reviews    love  \
# brand
# Anastasia Beverly Hills     Eye Palettes     5.0               8000  470200
# CHANEL                           Perfume     5.0                447   68800
# FENTY BEAUTY by Rihanna        Face Sets     5.0               1000  156900
# KVD Vegan Beauty            Face Brushes     5.0               1000   35500
# SEPHORA COLLECTION        Brush Cleaners     5.0               2000   81000
# Sephora Favorites               Lip Sets     5.0                220   41900
# Shiseido                 Makeup Removers     5.0               2000   97400
# Too Faced                   Eye Palettes     5.0               1000   57000
# Tower 28 Beauty                Lip Gloss     5.0                210   36800
#
#                          price  value_price  \
# brand
# Anastasia Beverly Hills   42.0         42.0
# CHANEL                    85.0         85.0
# FENTY BEAUTY by Rihanna   23.0         23.0
# ...

# %%
import matplotlib.pyplot as plt
ax = dfTop[['love']].plot(kind='bar', title ="Brand Love", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Brand", fontsize=12)
ax.set_ylabel("Love", fontsize=12)
plt.show()

# %% [markdown]
# Summary
# From this data, what can we see is that Anastasia Beverly Hills which is a Eye Palettes are the most well loved by the Sephora customers.
